# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.ptt.cc/bbs/NBA/index.html'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")

words=[]

for d in soup.find_all(class_="r-ent"):
    print(d.text.replace('\t', '').replace('\n', ''))
    print('作者: ' + d.find(class_='author').text,'標題: ' + d.find(class_='title').text,'日期: ' + d.find(class_='date').text)
    words.append([d.find(class_='author').text.replace('\t', '').replace('\n', ''),d.find(class_='title').text.replace('\t', '').replace('\n', ''),d.find(class_='date').text.replace('\t', '').replace('\n', '')])
# Out:
# 36[新聞] Tatum:會努力幫助球隊贏球，自己也想入選Muma5566⋯搜尋同標題文章搜尋看板內 Muma5566 的文章12/11
# 作者: Muma5566 標題:
#
# 				[新聞] Tatum:會努力幫助球隊贏球，自己也想入選
#
# 			 日期: 12/11
# 32[花邊] Nelson談論當年Howard在魔術的"魔獸人生"TheBatman⋯搜尋同標題文章搜尋看板內 TheBatman 的文章12/11
# 作者: TheBatman 標題:
#
# 				[花邊] Nelson談論當年Howard在魔術的"魔獸人生"
#
# 			 日期: 12/11
# 24[新聞] 卡特第1500場出賽 史上第5人LinBaoYan⋯搜尋同標題文章搜尋看板內 LinBaoYan 的文章12/11
# 作者: LinBaoYan 標題:
#
# 				[新聞] 卡特第1500場出賽 史上第5人
#
# 			 日期: 12/11
# 30[花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元thnlkj0665⋯搜尋同標題文章搜尋看板內 thnlkj0665 的文章12/11
# 作者: thnlkj0665 標題:
#
# 				[花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元
#
# 			 日期: 12/11
# 68[花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞kairiyu⋯搜尋同標題文章搜尋看板內 kairiyu 的文章12/11
# 作者: kairiyu 標題:
#
# 				[花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞
#
# 			 日期: 12/11
# 35[花邊]J.J. Culver 砍下100分innocent8675⋯搜尋同標題文章搜尋看板內 innocent8675 的文章12/11
# 作者: innocent8675 標題:
#
# 				[花邊]J.J. Culver 砍下100分
#
# 			 日期: 12/11
# 58[花邊] KD重申了自己想要擁有一支NBA球隊的願望NSYSUheng⋯搜尋同標題文章搜尋看板內 NSYSUheng 的文章12/11
# 作者: NSYSUheng 標題:
#
# 				[花邊] KD重申了自己想要擁有一支NBA球隊的願望
#
# 			 日期: 12/11
# 22Re: [花邊] Jimmy Butler的instagram貼文tmac4ever⋯搜尋同標題文章搜尋看板內 tmac4ever 的文章12/11
# 作者: tmac4ever 標題:
#
# 				Re: [花邊] Jimmy Butler的instagram貼文
#
# 			 日期: 12/11
# 45[新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了Israfil⋯搜尋同標題文章搜尋看板內 Israfil 的文章12/11
# 作者: Israfil 標題:
#
# 				[新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了
#
# 			 日期: 12/11
# 36[情報] New Balance 為Kawhi架設看板感謝多倫多thnlkj0665⋯搜尋同標題文章搜尋看板內 thnlkj0665 的文章12/11
# 作者: thnlkj0665 標題:
#
# 				[情報] New Balance 為Kawhi架設看板感謝多倫多
#
# 			 日期: 12/11
# 39[花邊] Tacko Fall：KG是傳奇，見到他對我意義lovea⋯搜尋同標題文章搜尋看板內 lovea 的文章12/11
# 作者: lovea 標題:
#
# 				[花邊] Tacko Fall：KG是傳奇，見到他對我意義
#
# 			 日期: 12/11
# (已被Vedan刪除) <qq326>1-1 1-2-12/11
# 作者: - 標題:
#
# 				(已被Vedan刪除) <qq326>1-1 1-2
#
# 			 日期: 12/11
# 31[討論] 08年京奧男籃的西班牙很謎嗎?Darren2012⋯搜尋同標題文章搜尋看板內 Darren2012 的文章12/11
# 作者: Darren2012 標題:
#
# 				[討論] 08年京奧男籃的西班牙很謎嗎?
#
# 			 日期: 12/11
# 15(本文已被刪除) [VeryGoodBoy]-12/11
# 作者: - 標題:
#
# 				(本文已被刪除) [VeryGoodBoy]
#
# 			 日期: 12/11
# 49[討論] LBJ在投三分球之前的準備動作pneumo⋯搜尋同標題文章搜尋看板內 pneumo 的文章12/11
# 作者: pneumo 標題:
#
# 				[討論] LBJ在投三分球之前的準備動作
#
# 			 日期: 12/11
# 48[花邊] 全能後衛！Ish Smith在暫停時幫忙拖地whoAU⋯搜尋同標題文章搜尋看板內 whoAU 的文章12/11
# 作者: whoAU 標題:
#
# 				[花邊] 全能後衛！Ish Smith在暫停時幫忙拖地
#
# 			 日期: 12/11
# 17[花邊] 前賽爾提克球員因未尊重中國國歌遭罰款LinBaoYan⋯搜尋同標題文章搜尋看板內 LinBaoYan 的文章12/11
# 作者: LinBaoYan 標題:
#
# 				[花邊] 前賽爾提克球員因未尊重中國國歌遭罰款
#
# 			 日期: 12/11
# [公告] 板規v6.6Vedan⋯搜尋同標題文章搜尋看板內 Vedan 的文章 5/24!
# 作者: Vedan 標題:
#
# 				[公告] 板規v6.6
#
# 			 日期:  5/24
# 爆[公告] 樂透取消及未來不再開啟樂透Vedan⋯搜尋同標題文章搜尋看板內 Vedan 的文章 6/24M
# 作者: Vedan 標題:
#
# 				[公告] 樂透取消及未來不再開啟樂透
#
# 			 日期:  6/24
# 37[公告] 版主上任相關事項 qazwsx879345⋯搜尋同標題文章搜尋看板內 qazwsx879345 的文章10/25
# 作者: qazwsx879345 標題:
#
# 				[公告] 版主上任相關事項
#
# 			 日期: 10/25
# 14[情報] SEASON Schedule 賽程 December 19–20JerroLi⋯搜尋同標題文章搜尋看板內 JerroLi 的文章11/29
# 作者: JerroLi 標題:
#
# 				[情報] SEASON Schedule 賽程 December 19–20
#
# 			 日期: 11/29
# 31[公告]是否禁止basketball top 5文章投票開始 dragon803⋯搜尋同標題文章搜尋看板內 dragon803 的文章12/08M
# 作者: dragon803 標題:
#
# 				[公告]是否禁止basketball top 5文章投票開始
#
# 			 日期: 12/08

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
'''
Your Code
'''
columns=['作者','標題','時間']
table=pd.DataFrame(words,columns=columns)
table
# Out:
#               作者                                      標題     時間
# 0       Muma5566             [新聞] Tatum:會努力幫助球隊贏球，自己也想入選  12/11
# 1      TheBatman         [花邊] Nelson談論當年Howard在魔術的"魔獸人生"  12/11
# 2      LinBaoYan                   [新聞] 卡特第1500場出賽 史上第5人  12/11
# 3     thnlkj0665               [花邊] 厄文持續缺賽 錯失激勵獎金12.5萬美元  12/11
# 4        kairiyu     [花邊] 當湖人主場播放歌手Lizzo歌曲時，本人在場邊直接表演露臀舞  12/11
# 5   innocent8675                  [花邊]J.J. Culver 砍下100分  12/11
# 6      NSYSUheng              [花邊] KD重申了自己想要擁有一支NBA球隊的願望  12/11
# 7      tmac4ever       Re: [花邊] Jimmy Butler的instagram貼文  12/11
# 8        Israfil                 [新聞] 三分砲火猛烈 伯坦斯：籃框實在太寬了  12/11
# 9     thnlkj0665        [情報] New Balance 為Kawhi架設看板感謝多倫多  12/11
# 10         lovea           [花邊] Tacko Fall：KG是傳奇，見到他對我意義  12/11
# 11             -              (已被Vedan刪除) <qq326>1-1 1-2  12/11
# 12    Darren2012                    [討論] 08年京奧男籃的西班牙很謎嗎?  12/11
# 13             -                  (本文已被刪除) [VeryGoodBoy]  12/11
# 14        pneumo                    [討論] LBJ在投三分球之前的準備動作  12/11
# 15         whoAU             [花邊] 全能後衛！Ish Smith在暫停時幫忙拖地  12/11
# 16     LinBaoYan                 [花邊] 前賽爾提克球員因未尊重中國國歌遭罰款  12/11
# 17         Vedan                             [公告] 板規v6.6   5/24
# 18         Vedan                      [公告] 樂透取消及未來不再開啟樂透   6/24
# 19  qazwsx879345                          [公告] 版主上任相關事項   10/25
# 20       JerroLi  [情報] SEASON Schedule 賽程 December 19–20  11/29
# 21     dragon803         [公告]是否禁止basketball top 5文章投票開始   12/08

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
'''
Your Code
'''
url1 = 'https://www.ptt.cc/bbs/Beauty/index.html'
r = requests.get(url1,cookies={'over18': '1'})

soup = BeautifulSoup(r.text, "html5lib")

words=[]

for d in soup.find_all(class_="r-ent"):
    words.append([d.find(class_='author').text.replace('\t', '').replace('\n', ''),d.find(class_='title').text.replace('\t', '').replace('\n', ''),d.find(class_='date').text.replace('\t', '').replace('\n', '')])

columns=['作者','標題','時間']
table=pd.DataFrame(words,columns=columns)
table
# Out:
#               作者                                  標題     時間
# 0       teramars                        [正妹] 氣質清新自然   12/11
# 1        g987669                          [正妹] 韓國的妹子  12/11
# 2              -                (本文已被刪除) [naruto406]  12/11
# 3     e030149116                           [正妹] 泰國華僑  12/11
# 4     hn85988643                          [神人] 虎航空服員  12/11
# 5      naruto406                     [正妹] 各位的老婆Julia  12/11
# 6    linchen1121              [帥哥] 濱邊美波JR SKISKI的共演者  12/11
# 7   ILoveHayoung                         [正妹] 衛藤美彩    12/11
# 8            aq1  [正妹] 新垣結衣 GMO「Life is friendship」篇  12/11
# 9   SuperSean219                      [正妹] 笑容很甜美的女孩兒  12/11
# 10   ReiKuromiya                            [正妹] =越南  12/11
# 11      hateOnas          [公告] 不願上表特 ＆ 優文推薦 ＆ 檢舉建議專區   5/21
# 12      hateOnas          Fw: [公告] 請使用者多加注意我國保護兒少的法令   7/24
# 13      hateOnas               [公告] 表特板板規(2019.7.26)   7/26
# 14      hateOnas                  [公告] 201907 板主徵選延長   7/26
# 15      hateOnas                        [公告] 請勿意淫推文   11/23
